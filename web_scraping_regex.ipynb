# %% [markdown]
# ### Web Scraping - Example 1 (Extracting Job Descriptions from Job Portal)

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import pandas as pd
import re

# %%
url = "https://www.iimjobs.com/k/analytics-jobs-190.html"

# %%
html = urlopen(url)

# %%
html

# %%
soup = BeautifulSoup(html)
type(soup)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# ### Problem
#
# Extract the Job description from each job posting?
#
# ### Approach
#
# a. Each of the Job Posting is a link. Find the url (href attribute) for each job
# b. Open the job link. Find the attribute that contains the Job Description

# %%
# using find_all to find specific tags
all_links = []
for link in soup.find_all("a"):
    all_links.append(link.get("href"))

# %%
all_links[1]
# Out:
# 'https://www.iimjobs.com/c/banking--finance-jobs-13.html'

# %%
len(all_links)
# Out:
# 742

# %% [raw]
# Q: This will output all links. How do extract links for only job ids?

# %% [markdown]
# #### Approach 1: based on specific attributes

# %%
job_links = []
for link in soup.find_all("a"):
    if link.get("data-jobid") is not None:
        job_links.append(link.get("href"))

# %%
len(pd.Series(job_links).unique())
# Out:
# 121

# %%
len(job_links)
# Out:
# 242

# %% [markdown]
# #### Approach 2: Using parent tag element details

# %%
joblisting = soup.find("div", id="listingPanel")

# %%
all_links = []
children = joblisting.find_all("a")
for child in children:
    all_links.append(child.get("href"))

# %%
len(all_links)
# Out:
# 251

# %%
len(pd.Series(all_links).unique())
# Out:
# 128

# %% [markdown]
# #### Approach 3: Using CSS selector

# %%
soup.select("#listingPanel > div.listing > div:nth-child(1)")
# Out:
# [<div class="unfollowopt jobRow container table table-hover pdlr0" data-jobid="866004">
#  <div class="col-lg-9 col-md-9 col-sm-8 container pdmobr5" style="padding-left:0px;">
#  <div class="pull-left col-xs-12 col-lg-3new col-md-3new col-sm-3new pd0 hidden-xs">
#  <span class="pull-left companyjobs"><i class="fa fa-suitcase greytxt"></i></span>
#  <span class="pull-left" data-trigger="hover click" rel="tooltip" title="premium job">
#  <i class="fa fa-bookmark darkgreyish"></i>
#  </span>
#  <span class="glyphicon glyphicon-plus-sign plsign plsigngrey pull-left" data-trigger="hover click" rel="tooltip"></span>
#  <span class="applied-job showicon pull-left" data-trigger="hover click" rel="tooltip" title="">
#  <i class="fa fa-check-square-o greytxt"></i>
#  </span>
#  <span act="save_job" class="glyphicon glyphicon-star-empty saved-job pull-left" data-trigger="hover click" rel="tooltip" title="save this job for future reference"></span>
#  <span class="gry_txt txt12 visible-xs pull-right mt3">20/11/2020</span>
#  </div>
#  <div class="clearfix visible-xs"></div>
#  <div class="pull-left col-lg-9new col-md-9new col-sm-9new pdlr0 pdmobl5 mtb2">
#  <span class="pull-left">
#  <a class="mrmob5 hidden-xs" data-jobid="866004" href="https://www.iimjobs.com/j/merilytics-business-analyst-data-analytics-iit-bits-nit-0-2-yrs-866004.html?ref=kp" name="view_link" target="_blank"> Merilytics - Business Analyst - Data Analytics - IIT/BITS/NIT (0-2 yrs) </a>
#  <!-- <input type="hidden" value="$listJobs['id'];" > -->
#  <div class="clearfix"></div>
#  <a class="mrmob5 hidden-lg hidden-md hidden-sm visible-xs" data-jobid="866004" href="https://www.iimjobs.com/j/merilytics-business-analyst-data-analytics-iit-bits-nit-0-2-yrs-866004.html?ref=kp" name="view_link" target="_blank"> Merilytics - Business Analyst - Data Analytics - IIT/BITS/NIT  </a>
#  <span class="mobexp">
#  <i aria-hidden="true" class="fa fa-calendar-o"></i> 0-2 yrs
#                                                  </span>
#  <span alt="Hyderabad" class="disp768" title="Hyderabad">
#  <i class="glyphicon glyphicon-map-marker"></i>
#                                              Hyderabad                                            </span>
#  </span>
#  </div>
#  </div>
#  <div class="col-lg-3 col-md-3 col-sm-4 pdlr0 mtb2 hidden-xs">
#  <div class="col-lg-7 col-md-7 col-sm-7 ellipsis pdlr0 pdmobl5">
#  <span alt="Hyderabad" title="Hyderabad">
#          Hyderabad                                        </span>
#  </div>
#  <div class="col-lg-5 col-md-5 col-sm-5 pdl6">
#  <!--<span class="gry_txt txt12"></span>-->
#  <span class="gry_txt txt12 original">20/11/2020
#                                          </span>
#  <div class="logo-linkage hidden">
#  </div>
#  </div>
#  </div>
#  </div>]

# %%
listPanel = soup.select("#listingPanel > div.listing > *")

# %%
listPanel[1]
# Out:
# <div class="unfollowopt jobRow container table table-hover pdlr0 greybg" data-jobid="865600">
# <div class="col-lg-9 col-md-9 col-sm-8 container pdmobr5" style="padding-left:0px;">
# <div class="pull-left col-xs-12 col-lg-3new col-md-3new col-sm-3new pd0 hidden-xs">
# <span class="pull-left companyjobs"><i class="fa fa-suitcase greytxt"></i></span>
# <span class="pull-left" data-trigger="hover click" rel="tooltip" title="premium job">
# <i class="fa fa-bookmark darkgreyish"></i>
# </span>
# <span class="pull-left prefrence" data-trigger="hover click" rel="tooltip" title="Women candidates preferred"><img src="https://static.iimjobs.com/resources/images/female_candidate.png"/></span>
# <span class="applied-job showicon pull-left" data-trigger="hover click" rel="tooltip" title="">
# <i class="fa fa-check-square-o greytxt"></i>
# </span>
# <span act="save_job" class="glyphicon glyphicon-star-empty saved-job pull-left" data-trigger="hover click" rel="tooltip" title="save this job for future reference"></span>
# <span class="gry_txt txt12 visible-xs pull-right mt3">19/11/2020</span>
# </div>
# <div class="clearfix visible-xs"></div>
# <div class="pull-left col-lg-9new col-md-9new col-sm-9new pdlr0 pdmobl5 mtb2">
# <span class="pull-left">
# <a class="mrmob5 hidden-xs" data-jobid="865600" href="https://www.iimjobs.com/j/zupee-head-data-science-analytics-8-16-yrs-865600.html?ref=kp" name="view_link" target="_blank"> Zupee - Head - Data Science &amp; Analytics (8-16 yrs) </a>
# <!-- <input type="hidden" value="$listJobs['id'];" > -->
# <div class="clearfix"></div>
# <a class="mrmob5 hidden-lg hidden-md hidden-sm visible-xs" data-jobid="865600" href="https://www.iimjobs.com/j/zupee-head-data-science-analytics-8-16-yrs-865600.html?ref=kp" name="view_link" target="_blank"> Zupee - Head - Data Science &amp; Analytics  </a>
# <span class="mobexp">
# <i aria-hidden="true" class="fa fa-calendar-o"></i> 8-16 yrs
#                                                 </span>
# <span alt="Delhi NCR/Haryana" class="disp768" title="Delhi NCR/Haryana">
# <i class="glyphicon glyphicon-map-marker"></i>
#                                             Delhi NCR/Haryana                                            </span>
# </span>
# </div>
# </div>
# <div class="col-lg-3 col-md-3 col-sm-4 pdlr0 mtb2 hidden-xs">
# <div class="col-lg-7 col-md-7 col-sm-7 ellipsis pdlr0 pdmobl5">
# <span alt="Delhi NCR/Haryana" title="Delhi NCR/Haryana">
#         Delhi NCR/Haryana                                        </span>
# </div>
# <div class="col-lg-5 col-md-5 col-sm-5 pdl6">
# <!--<span class="gry_txt txt12"></span>-->
# <span class="gry_txt txt12 original">19/11/2020
#                                         </span>
# <div class="logo-linkage hidden">
# </div>
# </div>
# </div>
# </div>

# %%
[x.get("href") for x in  listPanel[0].find_all("a")]
# Out:
# ['https://www.iimjobs.com/j/merilytics-business-analyst-data-analytics-iit-bits-nit-0-2-yrs-866004.html?ref=kp',
#  'https://www.iimjobs.com/j/merilytics-business-analyst-data-analytics-iit-bits-nit-0-2-yrs-866004.html?ref=kp']

# %%
[x.get("href") for x in listPanel[0].find_all("a")]
# Out:
# ['https://www.iimjobs.com/j/merilytics-business-analyst-data-analytics-iit-bits-nit-0-2-yrs-866004.html?ref=kp',
#  'https://www.iimjobs.com/j/merilytics-business-analyst-data-analytics-iit-bits-nit-0-2-yrs-866004.html?ref=kp']

# %%
all_links = []
for i in range(len(listPanel)):
    all_links.append([x.get("href") for x in listPanel[i].find_all("a")])

# %%
len(all_links)
# Out:
# 128

# %% [raw]
# # Q: Assignment: Find Job Description for the selected link

# %%
url = all_links[0][0]
url
# Out:
# 'https://www.iimjobs.com/j/merilytics-business-analyst-data-analytics-iit-bits-nit-0-2-yrs-866004.html?ref=kp'

# %%
html = urlopen(url)
soup = BeautifulSoup(html)

# %%
#page-content-wrapper > div.page-content.inset > div.info.col-md-9.col-sm-9.col-xs-12.pdlr0.mnht520 > div.details.job-description

# %% [markdown]
# ### Web Scraping - Example 2 (Extracting Reviews from Amazon)

# %%
url_template = "https://www.amazon.in/Test-Exclusive-550/product-reviews/B077Q7GW9V/ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=<NUM>"

# %%
url = re.sub("<NUM>",str(1),url_template)
url
# Out:
# 'https://www.amazon.in/Test-Exclusive-550/product-reviews/B077Q7GW9V/ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=1'

# %%
clean_reviews = []
for i in range(10):
    try:
        url = re.sub("<NUM>",str(i),url_template)
        html = urlopen(url)
        soup = BeautifulSoup(html)

        all_reviews = soup.find_all("div", class_="a-row a-spacing-small review-data")

        for review in all_reviews:
            review_text = review.find("span",class_="a-size-base review-text review-text-content")
            clean_reviews.append(review_text.find("span").get_text())
    except Exception as e:
        print(e)
        break
# Out:
# HTTP Error 503: Service Unavailable

# %%
len(clean_reviews)
# Out:
# 560

# %%
clean_reviews[500]
# Out:
# '\n  My opinion after buying a phone ::1. Best Performance.2. One of the best thing Snapdragon processor in Redmi Note series device at this price.3. Good battery life.4. if you like Big Display You get a 6.67-inch full-HD+ (1080x2400 -pixel). But The refresh rate of Redmi Note 9 Pro is 60Hz.5. Gorilla Glass 5 Protection.6. Good Design and The squared  camera design is also Amazing.7. Camera quality is good , portrait shots had nicely blurred background. But No LED flash lights in front.Overall This is balanced Mobile Phone\n'

# %% [markdown]
# ### Web Scraping - Example 2 (Extracting Reviews from Amazon)

# %%
link = "https://www.worldometers.info/coronavirus/"
hdr = {'User-Agent': 'Mozilla/5.0'}
req = Request(link,headers=hdr)
page = urlopen(req)

# %%
soup = BeautifulSoup(page)

# %%
covid_tbl = soup.find("table", id = "main_table_countries_today")

# %%
print(covid_tbl.prettify())

# %%
tbl_rows = covid_tbl.find_all("tr")

# %%
res = []
for row in tbl_rows:
    td = row.find_all("td")
    td_clean = [x.get_text() for x in td]
    res.append(td_clean)

# %%
res[12]
# Out:
# ['4',
#  'France',
#  '2,065,138',
#  '',
#  '46,698 ',
#  '',
#  '145,391',
#  '',
#  '1,873,049',
#  '4,775',
#  '31,611',
#  '715',
#  '19,339,461',
#  '296,031',
#  '65,329,229 ',
#  'Europe',
#  '32',
#  '1,399',
#  '3']

# %%
res_df = pd.DataFrame(res)

# %%
res_df
# Out:
#        0                  1           2        3          4       5   \
# 0    None               None        None     None       None    None
# 1          \nNorth America\n  13,943,144   +3,959    383,096    +506
# 2                   \nAsia\n  15,370,419   +9,760    271,231     +96
# 3          \nSouth America\n  10,504,498      +96    313,513      +9
# 4                 \nEurope\n  14,694,606  +18,539    337,780    +443
# ..    ...                ...         ...      ...        ...     ...
# 231                   Total:  14,694,606  +18,539    337,780    +443
# 232                   Total:   2,026,587              48,509
# 233                   Total:      43,074      +10      1,003
# 234                   Total:         721                  15
# 235                   Total:  56,583,049  +32,364  1,355,147  +1,054
#
#              6        7           8        9        10     11    12    13  \
# 0          None     None        None     None     None   None  None  None
# 1     8,730,177   +4,096   4,829,871   26,194
# 2    13,804,597  +14,541   1,294,591   25,136
# 3     9,498,954     +544     692,031   17,363
# 4     5,594,370   +7,962   8,762,456   30,141
# ..          ...      ...         ...      ...      ...    ...   ...   ...
# 231   5,594,370   +7,962   8,762,456   30,141
# 232   1,709,279              268,799    2,573
# 233      32,950                9,121       24
# 234         659                   47        4
# 235  39,370,986  +27,172  15,856,916  101,435  7,259.1  173.9
#
#        14                 15    16    17    18
# 0    None               None  None  None  None
# 1              North America    \n
# 2                       Asia    \n
# 3              South America    \n
# 4                     Europe    \n
# ..    ...                ...   ...   ...   ...
# 231                   Europe
# 232                   Africa
# 233        Australia/Oceania
# 234
# 235                      All    \n
#
# [236 rows x 19 columns]

# %%
for heading in covid_tbl.find_all("th"):
    print(heading.get_text())
# Out:
# #
# Country,Other
# TotalCases
# NewCases
# TotalDeaths
# NewDeaths
# TotalRecovered
# NewRecovered
# ActiveCases
# Serious,Critical
# Tot Cases/1M pop
# Deaths/1M pop
# TotalTests
# Tests/
# 1M pop
#
# Population
# Continent
# 1 Caseevery X ppl
# 1 Deathevery X ppl
# 1 Testevery X ppl

# %%
res_df.to_csv("chk.csv")

# %% [markdown]
# ### Regular expressions

# %%
sample_txt = '''

Mr. John.b.Doe
Designation: Sr Software Engineer
DOB: 20-12-1989
email: johndoe@gmail.com
Mob1: 9123456780
Mob2: 8123456780

Working as a Sr Software Engg with ABC Ltd. Total 5+ yrs of experience in Data science & advanced
analytics

'''

# %%
import re

# %%
for match in re.finditer("john", sample_txt, re.IGNORECASE):
    print(match)
# Out:
# <re.Match object; span=(6, 10), match='John'>
# <re.Match object; span=(74, 78), match='john'>

# %%
for match in re.finditer(" John ", sample_txt):
    print(match)

# %%
# basic search

# %%
matches = re.finditer("john",sample_txt,re.IGNORECASE)

# %%
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(6, 10), match='John'>
# <re.Match object; span=(74, 78), match='john'>

# %%
def quick_pat(pat,sample_txt):
    matches = re.finditer(pat,sample_txt,re.IGNORECASE)
    for match in matches:
        print(match)

# %%
quick_pat("john")
# Out:
# <re.Match object; span=(6, 10), match='John'>
# <re.Match object; span=(74, 78), match='john'>

# %%
# what if we only want to match the name 
# use the word boundary indicator
quick_pat(r"\bjohn\b")
# Out:
# <re.Match object; span=(6, 10), match='John'>

# %%
# Q: Any alternate approach to extract full match and exclude partial one?

# %%
# find mobile no
quick_pat(r"\d{10}")

# %%
# alternatively, using character set
quick_pat(r"[9][0-9]{9}")
# Out:
# <re.Match object; span=(98, 108), match='9123456780'>

# %% [raw]
# ## Questions
#
# Find only mobile number starting with 9

# %%
sample_txt = '''

abc@gmail.com    Rs.1000
klh_564@gmail.com  Rs.2000
bh.glk@yahoo.co.in Rs.3000
bh.glk@abcltd.in Rs.3000

'''

# %% [raw]
# \w: character or number
# * : 0 or more
# + : 1 or more
# ? : 0 or one

# %%
# find all emails
quick_pat(r"\w+@\w+\.(com|co.in)")
# Out:
# <re.Match object; span=(2, 15), match='abc@gmail.com'>
# <re.Match object; span=(27, 44), match='klh_564@gmail.com'>
# <re.Match object; span=(57, 72), match='glk@yahoo.co.in'>

# %%
quick_pat(r"[a-zA-Z._0-9]+@\w+\.(com|co.in)")
# Out:
# <re.Match object; span=(2, 15), match='abc@gmail.com'>
# <re.Match object; span=(27, 44), match='klh_564@gmail.com'>
# <re.Match object; span=(54, 72), match='bh.glk@yahoo.co.in'>

# %%
# find emails (only gmail or yahoo..)

# %%
quick_pat(r"[a-zA-Z._0-9]{1,}@(gmail|yahoo)\.(com|co.in)")

# %%
quick_pat(r"\w{1,}@(gmail|yahoo)\.(com|co.in)")

# %%
### Find IP address from the text

# %%
#https://datasetsearch.research.google.com/search?query=Server%20logs&docid=e82RkTuD5g%2BSYjjjAAAAAA%3D%3D

# %%
with open("access_log_sample.txt","r") as f:
    content = f.readlines()

# %%
content[0]
# Out:
# '54.36.149.41 - - [22/Jan/2019:03:56:14 +0330] "GET /filter/27|13%20%D9%85%DA%AF%D8%A7%D9%BE%DB%8C%DA%A9%D8%B3%D9%84,27|%DA%A9%D9%85%D8%AA%D8%B1%20%D8%A7%D8%B2%205%20%D9%85%DA%AF%D8%A7%D9%BE%DB%8C%DA%A9%D8%B3%D9%84,p53 HTTP/1.1" 200 30577 "-" "Mozilla/5.0 (compatible; AhrefsBot/6.1; +http://ahrefs.com/robot/)" "-"\n'

# %%
for i in content:
    quick_pat(r'\d{,3}\.\d{,3}\.\d{,3}\.\d{,3}',i)
# Out:
# <re.Match object; span=(0, 12), match='54.36.149.41'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 13), match='40.77.167.129'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 13), match='40.77.167.129'>
# <re.Match object; span=(0, 13), match='40.77.167.129'>
# <re.Match object; span=(0, 13), match='40.77.167.129'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='40.77.167.129'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 13), match='40.77.167.129'>
# <re.Match object; span=(0, 13), match='178.253.33.51'>
# <re.Match object; span=(0, 13), match='40.77.167.129'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 13), match='40.77.167.129'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 13), match='40.77.167.129'>
# <re.Match object; span=(0, 13), match='40.77.167.129'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 13), match='178.253.33.51'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 13), match='178.253.33.51'>
# <re.Match object; span=(0, 11), match='5.78.198.52'>
# <re.Match object; span=(0, 13), match='178.253.33.51'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 11), match='5.78.198.52'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='34.247.132.53'>
# <re.Match object; span=(0, 12), match='54.36.149.70'>
# <re.Match object; span=(0, 12), match='2.177.12.140'>
# <re.Match object; span=(0, 12), match='2.177.12.140'>
# <re.Match object; span=(0, 12), match='2.177.12.140'>
# <re.Match object; span=(0, 13), match='178.253.33.51'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 12), match='2.177.12.140'>
# <re.Match object; span=(0, 12), match='2.177.12.140'>
# <re.Match object; span=(0, 13), match='178.253.33.51'>
# <re.Match object; span=(0, 12), match='2.177.12.140'>
# <re.Match object; span=(0, 12), match='2.177.12.140'>
# <re.Match object; span=(0, 12), match='2.177.12.140'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 12), match='2.177.12.140'>
# <re.Match object; span=(0, 12), match='2.177.12.140'>
# <re.Match object; span=(0, 12), match='2.177.12.140'>
# <re.Match object; span=(0, 12), match='2.177.12.140'>
# <re.Match object; span=(0, 11), match='5.78.198.52'>
# <re.Match object; span=(0, 12), match='2.177.12.140'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 11), match='5.78.198.52'>
# <re.Match object; span=(0, 14), match='89.199.193.251'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 11), match='5.78.198.52'>
# <re.Match object; span=(0, 13), match='207.46.13.115'>
# <re.Match object; span=(0, 13), match='207.46.13.115'>
# <re.Match object; span=(0, 11), match='5.78.198.52'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='173.249.54.67'>
# <re.Match object; span=(0, 12), match='5.112.52.254'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 12), match='5.112.52.254'>
# <re.Match object; span=(0, 13), match='207.46.13.115'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='173.249.54.67'>
# <re.Match object; span=(0, 13), match='207.46.13.115'>
# <re.Match object; span=(0, 13), match='207.46.13.115'>
# <re.Match object; span=(0, 11), match='5.78.198.52'>
# <re.Match object; span=(0, 13), match='173.249.54.67'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='207.46.13.115'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='173.249.54.67'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 13), match='207.46.13.115'>
# <re.Match object; span=(0, 11), match='5.78.198.52'>
# <re.Match object; span=(0, 12), match='2.179.141.98'>
# <re.Match object; span=(0, 12), match='2.179.141.98'>
# <re.Match object; span=(0, 11), match='5.78.198.52'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 11), match='5.78.198.52'>
# <re.Match object; span=(0, 12), match='54.36.148.87'>
# <re.Match object; span=(0, 12), match='17.58.102.43'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 12), match='2.177.12.140'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(285, 296), match='16.0.912.36'>
# <re.Match object; span=(0, 11), match='51.15.15.54'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 12), match='2.177.12.140'>
# <re.Match object; span=(0, 12), match='2.177.12.140'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 12), match='54.36.149.17'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 12), match='5.62.206.249'>
# <re.Match object; span=(0, 12), match='2.179.141.98'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 12), match='2.179.141.98'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 12), match='2.177.12.140'>
# <re.Match object; span=(0, 12), match='54.36.148.18'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 12), match='54.36.148.17'>
# <re.Match object; span=(0, 12), match='2.185.221.79'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 12), match='2.177.12.140'>
# <re.Match object; span=(0, 12), match='2.179.141.98'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 12), match='2.179.141.98'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='207.46.13.104'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='207.46.13.104'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 12), match='54.36.148.32'>
# <re.Match object; span=(0, 12), match='54.36.149.35'>
# <re.Match object; span=(0, 13), match='207.46.13.104'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 12), match='172.20.2.174'>
# <re.Match object; span=(0, 12), match='5.160.157.20'>
# <re.Match object; span=(0, 12), match='5.160.157.20'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 11), match='5.78.198.52'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 11), match='5.78.198.52'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.78.198.52'>
# <re.Match object; span=(0, 11), match='5.78.198.52'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.78.198.52'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.78.198.52'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 13), match='54.36.148.161'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='157.55.39.245'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='173.249.54.67'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(180, 191), match='16.0.912.36'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='157.55.39.245'>
# <re.Match object; span=(0, 13), match='5.209.200.218'>
# <re.Match object; span=(0, 12), match='17.58.102.43'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(319, 330), match='16.0.912.36'>
# <re.Match object; span=(0, 13), match='5.209.200.218'>
# <re.Match object; span=(0, 13), match='5.209.200.218'>
# <re.Match object; span=(0, 13), match='5.209.200.218'>
# <re.Match object; span=(0, 12), match='54.36.149.63'>
# <re.Match object; span=(0, 13), match='5.209.200.218'>
# <re.Match object; span=(0, 13), match='5.209.200.218'>
# <re.Match object; span=(0, 13), match='5.209.200.218'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='173.249.54.67'>
# <re.Match object; span=(0, 12), match='17.58.102.43'>
# <re.Match object; span=(0, 13), match='157.55.39.245'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='5.209.200.218'>
# <re.Match object; span=(0, 13), match='5.209.200.218'>
# <re.Match object; span=(0, 12), match='54.36.148.10'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 13), match='5.209.200.218'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 13), match='5.209.200.218'>
# <re.Match object; span=(0, 13), match='5.209.200.218'>
# <re.Match object; span=(0, 13), match='5.209.200.218'>
# <re.Match object; span=(0, 13), match='5.209.200.218'>
# <re.Match object; span=(0, 13), match='5.209.200.218'>
# <re.Match object; span=(0, 13), match='5.209.200.218'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 13), match='5.209.200.218'>
# <re.Match object; span=(0, 12), match='66.249.64.66'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 11), match='5.78.180.75'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 13), match='5.209.200.218'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='207.46.13.104'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 13), match='54.36.148.117'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(331, 342), match='16.0.912.36'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='207.46.13.104'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='5.209.200.218'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 13), match='5.209.200.218'>
# <re.Match object; span=(0, 13), match='5.209.200.218'>
# <re.Match object; span=(0, 13), match='104.194.24.33'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(252, 263), match='16.0.912.36'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='54.36.148.232'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 12), match='46.224.77.32'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 12), match='54.36.149.92'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 12), match='46.224.77.32'>
# <re.Match object; span=(0, 12), match='46.224.77.32'>
# <re.Match object; span=(0, 13), match='207.46.13.104'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 12), match='46.224.77.32'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 11), match='51.15.15.54'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 12), match='54.36.149.58'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 12), match='17.58.102.43'>
# <re.Match object; span=(0, 13), match='5.209.200.218'>
# <re.Match object; span=(0, 12), match='54.36.149.83'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 12), match='17.58.102.43'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 12), match='17.58.102.43'>
# <re.Match object; span=(0, 13), match='5.209.200.218'>
# <re.Match object; span=(0, 11), match='5.78.198.52'>
# <re.Match object; span=(0, 13), match='34.247.132.53'>
# <re.Match object; span=(0, 11), match='5.78.198.52'>
# <re.Match object; span=(0, 12), match='172.20.2.174'>
# <re.Match object; span=(0, 11), match='5.78.198.52'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 11), match='5.78.198.52'>
# <re.Match object; span=(0, 13), match='66.249.66.197'>
# <re.Match object; span=(0, 13), match='5.209.200.218'>
# <re.Match object; span=(0, 13), match='5.209.200.218'>
# <re.Match object; span=(0, 13), match='5.209.200.218'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='5.209.200.218'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 12), match='5.112.52.254'>
# <re.Match object; span=(0, 11), match='5.78.198.52'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='207.46.13.104'>
# <re.Match object; span=(0, 12), match='54.36.149.84'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 11), match='5.78.198.52'>
# <re.Match object; span=(0, 13), match='5.209.200.218'>
# <re.Match object; span=(0, 13), match='5.209.200.218'>
# <re.Match object; span=(0, 11), match='5.78.198.52'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 14), match='216.244.66.248'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='207.46.13.104'>
# <re.Match object; span=(0, 14), match='216.244.66.248'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 13), match='207.46.13.104'>
# <re.Match object; span=(0, 11), match='5.78.198.52'>
# <re.Match object; span=(0, 11), match='5.78.198.52'>
# <re.Match object; span=(0, 11), match='5.78.198.52'>
# <re.Match object; span=(0, 13), match='54.36.149.105'>
# <re.Match object; span=(0, 12), match='46.224.77.32'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 13), match='207.46.13.104'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 12), match='54.36.149.16'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 11), match='54.36.149.7'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='207.46.13.104'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 13), match='207.46.13.104'>
# <re.Match object; span=(0, 12), match='54.36.149.77'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='54.36.149.102'>
# <re.Match object; span=(0, 12), match='5.127.80.240'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 12), match='5.123.89.112'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='40.77.167.129'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='207.46.13.104'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='5.209.200.218'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 13), match='5.209.200.218'>
# <re.Match object; span=(0, 12), match='54.36.148.14'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 13), match='157.55.39.245'>
# <re.Match object; span=(0, 11), match='51.15.15.54'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 12), match='46.224.77.32'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 12), match='5.160.157.20'>
# <re.Match object; span=(0, 12), match='5.160.157.20'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 12), match='46.224.77.32'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 13), match='54.36.148.197'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(272, 283), match='.111.24.134'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 12), match='54.36.149.54'>
# <re.Match object; span=(0, 12), match='54.36.148.70'>
# <re.Match object; span=(0, 12), match='46.224.77.32'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='157.55.39.245'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 13), match='207.46.13.104'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(280, 291), match='16.0.912.36'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 12), match='172.20.2.174'>
# <re.Match object; span=(0, 13), match='5.217.191.165'>
# <re.Match object; span=(0, 13), match='5.217.191.165'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 13), match='157.55.39.175'>
# <re.Match object; span=(0, 14), match='178.131.133.79'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 13), match='157.55.39.175'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='157.55.39.175'>
# <re.Match object; span=(0, 13), match='5.209.127.187'>
# <re.Match object; span=(0, 12), match='46.224.77.32'>
# <re.Match object; span=(0, 12), match='46.224.77.32'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='157.55.39.175'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 13), match='54.36.148.135'>
# <re.Match object; span=(0, 13), match='157.55.39.175'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='157.55.39.175'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 12), match='46.224.77.32'>
# <re.Match object; span=(0, 13), match='5.209.127.187'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 13), match='157.55.39.175'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='157.55.39.175'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 13), match='157.55.39.175'>
# <re.Match object; span=(0, 12), match='46.224.77.32'>
# <re.Match object; span=(0, 13), match='5.209.127.187'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='157.55.39.175'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 13), match='5.209.127.187'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 13), match='157.55.39.175'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 13), match='157.55.39.175'>
# <re.Match object; span=(0, 13), match='5.209.127.187'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 12), match='17.58.102.43'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 12), match='17.58.102.43'>
# <re.Match object; span=(0, 13), match='5.209.127.187'>
# <re.Match object; span=(0, 13), match='5.209.127.187'>
# <re.Match object; span=(0, 12), match='5.208.84.157'>
# <re.Match object; span=(0, 13), match='5.209.127.187'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 13), match='5.123.209.223'>
# <re.Match object; span=(0, 13), match='5.209.127.187'>
# <re.Match object; span=(0, 13), match='5.209.127.187'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 11), match='5.78.180.75'>
# <re.Match object; span=(0, 13), match='5.209.127.187'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 12), match='54.36.148.57'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='5.209.127.187'>
# <re.Match object; span=(0, 12), match='17.58.102.43'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 12), match='54.36.148.28'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(180, 191), match='16.0.912.36'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 13), match='54.36.148.185'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 13), match='54.36.148.176'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='157.55.39.245'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 13), match='157.55.39.245'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 13), match='207.46.13.104'>
# <re.Match object; span=(0, 13), match='5.209.200.218'>
# <re.Match object; span=(0, 11), match='51.15.15.54'>
# <re.Match object; span=(0, 12), match='54.36.148.72'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 13), match='34.247.132.53'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='5.209.200.218'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='207.46.13.104'>
# <re.Match object; span=(0, 13), match='157.55.39.245'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 13), match='207.46.13.104'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 11), match='66.249.83.1'>
# <re.Match object; span=(460, 473), match='103.28.132.65'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 12), match='54.36.149.86'>
# <re.Match object; span=(0, 13), match='5.209.200.218'>
# <re.Match object; span=(0, 11), match='89.47.79.75'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 13), match='5.209.200.218'>
# <re.Match object; span=(0, 11), match='89.47.79.75'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='89.47.79.75'>
# <re.Match object; span=(0, 11), match='89.47.79.75'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(73, 76), match='...'>
# <re.Match object; span=(0, 11), match='89.47.79.75'>
# <re.Match object; span=(0, 11), match='89.47.79.75'>
# <re.Match object; span=(0, 11), match='66.249.83.5'>
# <re.Match object; span=(466, 479), match='103.28.132.65'>
# <re.Match object; span=(0, 11), match='89.47.79.75'>
# <re.Match object; span=(0, 11), match='89.47.79.75'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(81, 84), match='...'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 12), match='66.249.83.91'>
# <re.Match object; span=(528, 541), match='103.28.132.65'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 12), match='66.249.83.93'>
# <re.Match object; span=(525, 538), match='103.28.132.65'>
# <re.Match object; span=(0, 12), match='66.249.83.92'>
# <re.Match object; span=(528, 541), match='103.28.132.65'>
# <re.Match object; span=(0, 12), match='66.249.83.91'>
# <re.Match object; span=(523, 536), match='103.28.132.65'>
# <re.Match object; span=(0, 12), match='66.249.83.92'>
# <re.Match object; span=(524, 537), match='103.28.132.65'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 13), match='54.36.148.143'>
# <re.Match object; span=(0, 11), match='66.249.83.7'>
# <re.Match object; span=(499, 512), match='103.28.132.65'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 12), match='66.249.83.91'>
# <re.Match object; span=(522, 535), match='103.28.132.65'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 11), match='89.47.79.75'>
# <re.Match object; span=(0, 12), match='172.20.2.174'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 12), match='66.249.83.92'>
# <re.Match object; span=(513, 526), match='103.28.132.65'>
# <re.Match object; span=(0, 12), match='66.249.83.92'>
# <re.Match object; span=(517, 530), match='103.28.132.65'>
# <re.Match object; span=(0, 11), match='89.47.79.75'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 12), match='66.249.83.93'>
# <re.Match object; span=(535, 548), match='103.28.132.65'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 12), match='66.249.83.93'>
# <re.Match object; span=(518, 531), match='103.28.132.65'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 13), match='54.36.148.118'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 12), match='17.58.102.43'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 12), match='54.36.148.65'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 13), match='40.77.167.129'>
# <re.Match object; span=(0, 13), match='40.77.167.129'>
# <re.Match object; span=(0, 12), match='54.36.148.22'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 13), match='46.51.119.113'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 12), match='54.36.149.68'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(80, 83), match='...'>
# <re.Match object; span=(0, 12), match='54.36.148.23'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(77, 80), match='...'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 13), match='54.36.148.211'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 11), match='89.47.79.75'>
# <re.Match object; span=(0, 11), match='89.47.79.75'>
# <re.Match object; span=(0, 11), match='89.47.79.75'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 11), match='89.47.79.75'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 11), match='89.47.79.75'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='178.253.33.51'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 12), match='54.36.149.11'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 11), match='89.47.79.75'>
# <re.Match object; span=(0, 11), match='89.47.79.75'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 11), match='89.47.79.75'>
# <re.Match object; span=(0, 11), match='89.47.79.75'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 13), match='54.36.148.137'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 13), match='5.115.150.169'>
# <re.Match object; span=(0, 12), match='5.123.232.17'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 13), match='207.46.13.115'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 13), match='207.46.13.115'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='207.46.13.115'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 13), match='207.46.13.115'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 12), match='54.36.148.14'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 12), match='5.160.157.20'>
# <re.Match object; span=(0, 12), match='5.160.157.20'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 14), match='204.18.198.248'>
# <re.Match object; span=(0, 13), match='207.46.13.115'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 12), match='17.58.102.43'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(265, 276), match='16.0.912.36'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 10), match='17.58.97.4'>
# <re.Match object; span=(0, 13), match='54.36.148.237'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 12), match='52.7.238.253'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='51.15.15.54'>
# <re.Match object; span=(0, 12), match='52.7.238.253'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 14), match='130.185.74.243'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 11), match='5.211.97.39'>
# <re.Match object; span=(0, 13), match='66.111.54.249'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 11), match='31.56.96.51'>
# <re.Match object; span=(0, 13), match='5.123.209.223'>
# ...
# <re.Match object; span=(0, 12), match='5.117.202.46'>
# <re.Match object; span=(0, 14), match='46.225.135.218'>
# <re.Match object; span=(0, 14), match='46.225.135.218'>
# <re.Match object; span=(0, 14), match='46.225.135.218'>
# <re.Match object; span=(0, 13), match='204.18.175.72'>
# <re.Match object; span=(0, 13), match='204.18.175.72'>
# <re.Match object; span=(0, 13), match='204.18.175.72'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 12), match='5.62.222.160'>
# <re.Match object; span=(0, 14), match='192.15.247.191'>
# <re.Match object; span=(0, 12), match='172.20.2.174'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 14), match='192.15.247.191'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 13), match='54.36.148.167'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 12), match='17.58.102.43'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 12), match='5.113.18.169'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 12), match='5.113.18.169'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 13), match='40.77.167.170'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 13), match='40.77.167.170'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 12), match='17.58.102.43'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(332, 343), match='16.0.912.36'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='40.77.167.170'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(182, 193), match='16.0.912.36'>
# <re.Match object; span=(0, 13), match='5.117.167.217'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 12), match='54.36.148.99'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 14), match='192.15.247.191'>
# <re.Match object; span=(0, 13), match='34.247.132.53'>
# <re.Match object; span=(0, 14), match='192.15.247.191'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 14), match='192.15.247.191'>
# <re.Match object; span=(0, 14), match='192.15.247.191'>
# <re.Match object; span=(0, 14), match='192.15.247.191'>
# <re.Match object; span=(0, 14), match='192.15.247.191'>
# <re.Match object; span=(0, 14), match='192.15.247.191'>
# <re.Match object; span=(0, 14), match='192.15.247.191'>
# <re.Match object; span=(0, 15), match='104.248.138.218'>
# <re.Match object; span=(0, 13), match='5.117.222.245'>
# <re.Match object; span=(0, 14), match='192.15.247.191'>
# <re.Match object; span=(0, 14), match='192.15.247.191'>
# <re.Match object; span=(0, 14), match='192.15.247.191'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 14), match='192.15.247.191'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 14), match='192.15.247.191'>
# <re.Match object; span=(0, 14), match='192.15.247.191'>
# <re.Match object; span=(0, 14), match='192.15.247.191'>
# <re.Match object; span=(0, 14), match='192.15.247.191'>
# <re.Match object; span=(0, 14), match='192.15.247.191'>
# <re.Match object; span=(0, 14), match='192.15.247.191'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='5.117.222.245'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 11), match='5.212.57.77'>
# <re.Match object; span=(0, 13), match='157.55.39.245'>
# <re.Match object; span=(0, 11), match='5.212.57.77'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 11), match='5.212.57.77'>
# <re.Match object; span=(0, 11), match='5.212.57.77'>
# <re.Match object; span=(0, 11), match='5.212.57.77'>
# <re.Match object; span=(0, 11), match='5.212.57.77'>
# <re.Match object; span=(0, 11), match='5.212.57.77'>
# <re.Match object; span=(0, 12), match='54.36.148.32'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 13), match='40.77.167.170'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 11), match='5.211.32.40'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 11), match='5.212.57.77'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='157.55.39.245'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 13), match='5.127.223.190'>
# <re.Match object; span=(0, 13), match='157.55.39.245'>
# <re.Match object; span=(0, 13), match='5.117.222.245'>
# <re.Match object; span=(0, 13), match='5.127.223.190'>
# <re.Match object; span=(0, 13), match='5.127.223.190'>
# <re.Match object; span=(0, 13), match='5.127.223.190'>
# <re.Match object; span=(0, 13), match='5.127.223.190'>
# <re.Match object; span=(0, 13), match='5.127.223.190'>
# <re.Match object; span=(0, 13), match='5.127.223.190'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 13), match='5.113.144.102'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 11), match='51.15.15.54'>
# <re.Match object; span=(0, 13), match='5.127.223.190'>
# <re.Match object; span=(0, 13), match='5.127.223.190'>
# <re.Match object; span=(0, 13), match='5.127.223.190'>
# <re.Match object; span=(0, 13), match='5.127.223.190'>
# <re.Match object; span=(0, 13), match='5.127.223.190'>
# <re.Match object; span=(0, 13), match='5.127.223.190'>
# <re.Match object; span=(0, 13), match='5.127.223.190'>
# <re.Match object; span=(0, 13), match='157.55.39.245'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 12), match='17.58.102.43'>
# <re.Match object; span=(0, 13), match='5.127.223.190'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='5.127.223.190'>
# <re.Match object; span=(0, 13), match='5.127.223.190'>
# <re.Match object; span=(0, 13), match='5.127.223.190'>
# <re.Match object; span=(0, 13), match='40.77.167.170'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 15), match='146.185.154.135'>
# <re.Match object; span=(0, 12), match='17.58.102.43'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 13), match='5.127.223.190'>
# <re.Match object; span=(0, 13), match='5.127.223.190'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 12), match='172.20.2.174'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(309, 320), match='16.0.912.36'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='51.38.125.215'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 12), match='5.62.222.160'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 13), match='5.127.223.190'>
# <re.Match object; span=(0, 13), match='5.127.223.190'>
# <re.Match object; span=(0, 13), match='5.127.223.190'>
# <re.Match object; span=(0, 13), match='5.127.223.190'>
# <re.Match object; span=(0, 13), match='5.127.223.190'>
# <re.Match object; span=(0, 13), match='5.127.223.190'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 11), match='91.99.72.15'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 13), match='5.127.223.190'>
# <re.Match object; span=(0, 13), match='5.127.223.190'>
# <re.Match object; span=(0, 13), match='5.127.223.190'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 14), match='93.110.220.181'>
# <re.Match object; span=(0, 12), match='5.160.157.20'>
# <re.Match object; span=(0, 12), match='5.160.157.20'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 11), match='192.15.6.66'>
# <re.Match object; span=(72, 76), match='1...'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='54.36.148.186'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='54.36.148.118'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='40.77.167.170'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 13), match='40.77.167.170'>
# <re.Match object; span=(0, 13), match='66.249.66.194'>
# <re.Match object; span=(0, 12), match='66.249.66.91'>
# <re.Match object; span=(0, 13), match='207.46.13.136'>
# <re.Match object; span=(0, 13), match='37.129.232.66'>
# <re.Match object; span=(0, 12), match='5.120.22.214'>
# <re.Match object; span=(0, 11), match='192.15.6.66'>
# <re.Match object; span=(0, 13), match='37.129.232.66'>
# <re.Match object; span=(0, 13), match='37.129.232.66'>
# <re.Match object; span=(0, 13), match='37.129.232.66'>

# %%
res_df = pd.DataFrame({"ip":all_ips,"ts":all_dates})
